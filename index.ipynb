# %% [markdown]
# # Accessing Data within Pandas - Lab

# %% [markdown]
# ## Introduction
#
# In this lab, we'll look at a data set which contains information World cup matches. Let's use the pandas commands learned in the previous lecture to learn more about our data!

# %% [markdown]
# ## Objectives
# You will be able to:
# * Understand and explain some key Pandas methods
# * Access DataFrame data by using the label
# * Perform boolean indexing on both Series and DataFrames
# * Use simple selectors for series
# * Set new Series and DataFrame inputs

# %% [markdown]
# ## Load the data

# %% [markdown]
# Load the file `WorldCupMatches.csv` as a dataframe in Pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('WorldCupMatches.csv')

# %%
df.head()
# Out:
#    Year              Datetime    Stage         Stadium         City  \
# 0  1930  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France                4                1         Mexico
# 1            USA                3                0        Belgium
# 2     Yugoslavia                2                1         Brazil
# 3        Romania                3                1           Peru
# 4      Argentina                1                0         France
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                     3                     0
# 1                    18346.0                     2                     0
# 2                    24059.0                     2                     0
# 3                     2549.0                     1                     0
# 4                    23409.0                     0                     0
#
#                   Referee               Assistant 1  \
# 0  LOMBARDI Domingo (URU)     CRISTOPHE Henry (BEL)
# 1       MACIAS Jose (ARG)  MATEUCCI Francisco (URU)
# 2     TEJADA Anibal (URU)   VALLARINO Ricardo (URU)
# 3   WARNKEN Alberto (CHI)       LANGENUS Jean (BEL)
# 4     REGO Gilberto (BRA)      SAUCEDO Ulises (BOL)
#
#                   Assistant 2  RoundID  MatchID Home Team Initials  \
# 0         REGO Gilberto (BRA)      201     1096                FRA
# 1       WARNKEN Alberto (CHI)      201     1090                USA
# 2         BALWAY Thomas (FRA)      201     1093                YUG
# 3    MATEUCCI Francisco (URU)      201     1098                ROU
# 4  RADULESCU Constantin (ROU)      201     1085                ARG
#
#   Away Team Initials
# 0                MEX
# 1                BEL
# 2                BRA
# 3                PER
# 4                FRA

# %% [markdown]
# ## Common methods and attributes

# %% [markdown]
# Use the correct method to look at the first 7 rows of the data set.

# %%
df.head(7)
# Out:
#    Year              Datetime    Stage         Stadium         City  \
# 0  1930  13 Jul 1930 - 15:00   Group 1         Pocitos  Montevideo
# 1  1930  13 Jul 1930 - 15:00   Group 4  Parque Central  Montevideo
# 2  1930  14 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
# 3  1930  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
# 5  1930  16 Jul 1930 - 14:45   Group 1  Parque Central  Montevideo
# 6  1930  17 Jul 1930 - 12:45   Group 2  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 0         France                4                1         Mexico
# 1            USA                3                0        Belgium
# 2     Yugoslavia                2                1         Brazil
# 3        Romania                3                1           Peru
# 4      Argentina                1                0         France
# 5          Chile                3                0         Mexico
# 6     Yugoslavia                4                0        Bolivia
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 0                     4444.0                     3                     0
# 1                    18346.0                     2                     0
# 2                    24059.0                     2                     0
# 3                     2549.0                     1                     0
# 4                    23409.0                     0                     0
# 5                     9249.0                     1                     0
# 6                    18306.0                     0                     0
#
#                     Referee               Assistant 1  \
# 0    LOMBARDI Domingo (URU)     CRISTOPHE Henry (BEL)
# 1         MACIAS Jose (ARG)  MATEUCCI Francisco (URU)
# 2       TEJADA Anibal (URU)   VALLARINO Ricardo (URU)
# 3     WARNKEN Alberto (CHI)       LANGENUS Jean (BEL)
# 4       REGO Gilberto (BRA)      SAUCEDO Ulises (BOL)
# 5     CRISTOPHE Henry (BEL)   APHESTEGUY Martin (URU)
# 6  MATEUCCI Francisco (URU)    LOMBARDI Domingo (URU)
#
#                   Assistant 2  RoundID  MatchID Home Team Initials  \
# 0         REGO Gilberto (BRA)      201     1096                FRA
# 1       WARNKEN Alberto (CHI)      201     1090                USA
# 2         BALWAY Thomas (FRA)      201     1093                YUG
# 3    MATEUCCI Francisco (URU)      201     1098                ROU
# 4  RADULESCU Constantin (ROU)      201     1085                ARG
# 5         LANGENUS Jean (BEL)      201     1095                CHI
# 6       WARNKEN Alberto (CHI)      201     1092                YUG
#
#   Away Team Initials
# 0                MEX
# 1                BEL
# 2                BRA
# 3                PER
# 4                FRA
# 5                MEX
# 6                BOL

# %% [markdown]
# Look at the last 3 rows of the data set.

# %%
df.tail(3)
# Out:
#      Year              Datetime                     Stage  \
# 849  2014  09 Jul 2014 - 17:00                Semi-finals
# 850  2014  12 Jul 2014 - 17:00   Play-off for third place
# 851  2014  13 Jul 2014 - 16:00                      Final
#
#                  Stadium             City Home Team Name  Home Team Goals  \
# 849   Arena de Sao Paulo       Sao Paulo     Netherlands                0
# 850     Estadio Nacional        Brasilia          Brazil                0
# 851  Estadio do Maracana  Rio De Janeiro         Germany                1
#
#      Away Team Goals Away Team Name                       Win conditions  \
# 849                0      Argentina  Argentina win on penalties (2 - 4)
# 850                3    Netherlands
# 851                0      Argentina        Germany win after extra time
#
#      Attendance  Half-time Home Goals  Half-time Away Goals  \
# 849     63267.0                     0                     0
# 850     68034.0                     0                     2
# 851     74738.0                     0                     0
#
#                    Referee            Assistant 1              Assistant 2  \
# 849     C�neyt �AKIR (TUR)   DURAN Bahattin (TUR)        ONGUN Tarik (TUR)
# 850  HAIMOUDI Djamel (ALG)   ACHIK Redouane (MAR)  ETCHIALI Abdelhak (ALG)
# 851   Nicola RIZZOLI (ITA)  Renato FAVERANI (ITA)     Andrea STEFANI (ITA)
#
#      RoundID    MatchID Home Team Initials Away Team Initials
# 849   255955  300186490                NED                ARG
# 850   255957  300186502                BRA                NED
# 851   255959  300186501                GER                ARG

# %% [markdown]
# Get a concise summary of your data using `.info()`

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 852 entries, 0 to 851
# Data columns (total 20 columns):
# Year                    852 non-null int64
# Datetime                852 non-null object
# Stage                   852 non-null object
# Stadium                 852 non-null object
# City                    852 non-null object
# Home Team Name          852 non-null object
# Home Team Goals         852 non-null int64
# Away Team Goals         852 non-null int64
# Away Team Name          852 non-null object
# Win conditions          852 non-null object
# Attendance              850 non-null float64
# Half-time Home Goals    852 non-null int64
# Half-time Away Goals    852 non-null int64
# Referee                 852 non-null object
# Assistant 1             852 non-null object
# Assistant 2             852 non-null object
# RoundID                 852 non-null int64
# MatchID                 852 non-null int64
# Home Team Initials      852 non-null object
# Away Team Initials      852 non-null object
# dtypes: float64(1), int64(7), object(12)
# memory usage: 133.2+ KB

# %% [markdown]
# Obtain a tuple representing the number of rows and number of columns

# %%
df.shape
# Out:
# (852, 20)

# %% [markdown]
# Use the appropriate attribute to get the column names

# %%
df.columns
# Out:
# Index(['Year', 'Datetime', 'Stage', 'Stadium', 'City', 'Home Team Name',
#        'Home Team Goals', 'Away Team Goals', 'Away Team Name',
#        'Win conditions', 'Attendance', 'Half-time Home Goals',
#        'Half-time Away Goals', 'Referee', 'Assistant 1', 'Assistant 2',
#        'RoundID', 'MatchID', 'Home Team Initials', 'Away Team Initials'],
#       dtype='object')

# %% [markdown]
# ## Selecting dataframe information

# %% [markdown]
# When looking at the dataframe's `.head()`, you might have noticed that the games are structured chronologically in the dataframe.
#
# Use the right selection method to print all the information from the 3rd to the 5th game.

# %%
df.iloc[3:6]
# Out:
#    Year              Datetime    Stage         Stadium         City  \
# 3  1930  14 Jul 1930 - 14:50   Group 3         Pocitos  Montevideo
# 4  1930  15 Jul 1930 - 16:00   Group 1  Parque Central  Montevideo
# 5  1930  16 Jul 1930 - 14:45   Group 1  Parque Central  Montevideo
#
#   Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 3        Romania                3                1           Peru
# 4      Argentina                1                0         France
# 5          Chile                3                0         Mexico
#
#   Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 3                     2549.0                     1                     0
# 4                    23409.0                     0                     0
# 5                     9249.0                     1                     0
#
#                  Referee              Assistant 1                 Assistant 2  \
# 3  WARNKEN Alberto (CHI)      LANGENUS Jean (BEL)    MATEUCCI Francisco (URU)
# 4    REGO Gilberto (BRA)     SAUCEDO Ulises (BOL)  RADULESCU Constantin (ROU)
# 5  CRISTOPHE Henry (BEL)  APHESTEGUY Martin (URU)         LANGENUS Jean (BEL)
#
#    RoundID  MatchID Home Team Initials Away Team Initials
# 3      201     1098                ROU                PER
# 4      201     1085                ARG                FRA
# 5      201     1095                CHI                MEX

# %% [markdown]
# Now, print all the info from game 5-9, but we're only interested to print out the "Home Team Name" and the "Away Team Name",

# %%
df.loc[5:10, ["Home Team Name" , "Away Team Name"]]
# Out:
#    Home Team Name Away Team Name
# 5           Chile         Mexico
# 6      Yugoslavia        Bolivia
# 7             USA       Paraguay
# 8         Uruguay           Peru
# 9           Chile         France
# 10      Argentina         Mexico

# %% [markdown]
# Next, we'd like the information on all the games played in Group 3 for the 1950 World Cup.

# %%
df.loc[(df["Year"] == 1950) & (df["Stage"] == "Group 3")]
# Out:
#     Year              Datetime    Stage           Stadium        City  \
# 56  1950  25 Jun 1950 - 15:00   Group 3          Pacaembu  Sao Paulo
# 61  1950  29 Jun 1950 - 15:30   Group 3  Durival de Brito   Curitiba
# 65  1950  02 Jul 1950 - 15:00   Group 3          Pacaembu  Sao Paulo
#
#    Home Team Name  Home Team Goals  Away Team Goals Away Team Name  \
# 56         Sweden                3                2          Italy
# 61         Sweden                2                2       Paraguay
# 65          Italy                2                0       Paraguay
#
#    Win conditions  Attendance  Half-time Home Goals  Half-time Away Goals  \
# 56                    36502.0                     2                     1
# 61                     7903.0                     2                     1
# 65                    25811.0                     1                     0
#
#                   Referee             Assistant 1                Assistant 2  \
# 56        LUTZ Jean (SUI)     BERANEK Alois (AUT)        TEJADA Carlos (MEX)
# 61  MITCHELL Robert (SCO)       LEMESIC Leo (YUG)     GARCIA Prudencio (USA)
# 65     ELLIS Arthur (ENG)  GARCIA Prudencio (USA)  DE LA SALLE Charles (FRA)
#
#     RoundID  MatchID Home Team Initials Away Team Initials
# 56      208     1219                SWE                ITA
# 61      208     1228                SWE                PAR
# 65      208     1218                ITA                PAR

# %% [markdown]
# Let's repeat the command above, but now we only want to print out the attendance column for the Group 3 games

# %%
df.loc[(df["Year"] == 1950) & (df["Stage"] == "Group 3"), ["Attendance"]]
# Out:
#     Attendance
# 56     36502.0
# 61      7903.0
# 65     25811.0

# %% [markdown]
# You can combine conditions like this:
#
# `df[(condition1) | (condition2)]`  -> Returns rows where either condition is true
#
# `df[(condition1) & (condition2)]`  -> Returns rows where both conditions are true

# %% [markdown]
# Throughout the entire history of the world cup, How many Home games were played by the Netherlands?

# %%
len(df.loc[df["Home Team Name"] == "Netherlands"])
# Out:
# 32

# %% [markdown]
# How many games were played by the Netherlands in total?

# %%
len(df.loc[(df["Home Team Name"] == "Netherlands") | (df["Away Team Name"] == "Netherlands")])
# Out:
# 54

# %% [markdown]
# Next, let's try and figure out how many games the USA played in the 2014 world cup.

# %%
len([df.loc[(df["Home Team Name"] == "USA") | (df["Away Team Name"] == "USA"))
# Out:
#      Year              Datetime                     Stage  \
# 772  2014  12 Jun 2014 - 17:00                    Group A
# 773  2014  13 Jun 2014 - 13:00                    Group A
# 774  2014  13 Jun 2014 - 16:00                    Group B
# 775  2014  13 Jun 2014 - 18:00                    Group B
# 776  2014  14 Jun 2014 - 13:00                    Group C
# 777  2014  14 Jun 2014 - 16:00                    Group D
# 778  2014  14 Jun 2014 - 18:00                    Group D
# 779  2014  14 Jun 2014 - 22:00                    Group C
# 780  2014  15 Jun 2014 - 13:00                    Group E
# 781  2014  15 Jun 2014 - 16:00                    Group E
# 782  2014  15 Jun 2014 - 19:00                    Group F
# 783  2014  16 Jun 2014 - 13:00                    Group G
# 784  2014  16 Jun 2014 - 16:00                    Group F
# 785  2014  16 Jun 2014 - 19:00                    Group G
# 786  2014  17 Jun 2014 - 13:00                    Group H
# 787  2014  17 Jun 2014 - 16:00                    Group A
# 788  2014  17 Jun 2014 - 18:00                    Group H
# 789  2014  18 Jun 2014 - 13:00                    Group B
# 790  2014  18 Jun 2014 - 16:00                    Group B
# 791  2014  18 Jun 2014 - 18:00                    Group A
# 792  2014  19 Jun 2014 - 13:00                    Group C
# 793  2014  19 Jun 2014 - 16:00                    Group D
# 794  2014  19 Jun 2014 - 19:00                    Group C
# 795  2014  20 Jun 2014 - 13:00                    Group D
# 796  2014  20 Jun 2014 - 16:00                    Group E
# 797  2014  20 Jun 2014 - 19:00                    Group E
# 798  2014  21 Jun 2014 - 13:00                    Group F
# 799  2014  21 Jun 2014 - 16:00                    Group G
# 800  2014  21 Jun 2014 - 18:00                    Group F
# 801  2014  22 Jun 2014 - 13:00                    Group H
# ..    ...                   ...                       ...
# 822  2014  30 Jun 2014 - 13:00                Round of 16
# 823  2014  30 Jun 2014 - 17:00                Round of 16
# 824  2014  04 Jul 2014 - 17:00             Quarter-finals
# 825  2014  04 Jul 2014 - 13:00             Quarter-finals
# 826  2014  08 Jul 2014 - 17:00                Semi-finals
# 827  2014  12 Jul 2014 - 17:00   Play-off for third place
# 828  2014  13 Jul 2014 - 16:00                      Final
# 829  2014  09 Jul 2014 - 17:00                Semi-finals
# 830  2014  05 Jul 2014 - 17:00             Quarter-finals
# 831  2014  05 Jul 2014 - 13:00             Quarter-finals
# 832  2014  29 Jun 2014 - 13:00                Round of 16
# 833  2014  29 Jun 2014 - 17:00                Round of 16
# 834  2014  01 Jul 2014 - 13:00                Round of 16
# 835  2014  01 Jul 2014 - 17:00                Round of 16
# 836  2014  28 Jun 2014 - 13:00                Round of 16
# 837  2014  28 Jun 2014 - 17:00                Round of 16
# 838  2014  29 Jun 2014 - 13:00                Round of 16
# 839  2014  29 Jun 2014 - 17:00                Round of 16
# 840  2014  30 Jun 2014 - 13:00                Round of 16
# 841  2014  30 Jun 2014 - 17:00                Round of 16
# 842  2014  01 Jul 2014 - 13:00                Round of 16
# 843  2014  01 Jul 2014 - 17:00                Round of 16
# 844  2014  04 Jul 2014 - 13:00             Quarter-finals
# 845  2014  04 Jul 2014 - 17:00             Quarter-finals
# 846  2014  05 Jul 2014 - 13:00             Quarter-finals
# 847  2014  05 Jul 2014 - 17:00             Quarter-finals
# 848  2014  08 Jul 2014 - 17:00                Semi-finals
# 849  2014  09 Jul 2014 - 17:00                Semi-finals
# 850  2014  12 Jul 2014 - 17:00   Play-off for third place
# 851  2014  13 Jul 2014 - 16:00                      Final
#
#                  Stadium             City Home Team Name  Home Team Goals  \
# 772   Arena de Sao Paulo       Sao Paulo          Brazil                3
# 773    Estadio das Dunas           Natal          Mexico                1
# 774     Arena Fonte Nova        Salvador           Spain                1
# 775       Arena Pantanal          Cuiaba           Chile                3
# 776     Estadio Mineirao  Belo Horizonte        Colombia                3
# 777     Estadio Castelao       Fortaleza         Uruguay                1
# 778       Arena Amazonia          Manaus         England                1
# 779     Arena Pernambuco          Recife   C�te d'Ivoire                2
# 780     Estadio Nacional        Brasilia     Switzerland                2
# 781    Estadio Beira-Rio    Porto Alegre          France                3
# 782  Estadio do Maracana  Rio De Janeiro       Argentina                2
# 783     Arena Fonte Nova        Salvador         Germany                4
# 784     Arena da Baixada        Curitiba         IR Iran                0
# 785    Estadio das Dunas           Natal           Ghana                1
# 786     Estadio Mineirao  Belo Horizonte         Belgium                2
# 787     Estadio Castelao       Fortaleza          Brazil                0
# 788       Arena Pantanal          Cuiaba          Russia                1
# 789    Estadio Beira-Rio    Porto Alegre       Australia                2
# 790  Estadio do Maracana  Rio De Janeiro           Spain                0
# 791       Arena Amazonia          Manaus        Cameroon                0
# 792     Estadio Nacional        Brasilia        Colombia                2
# 793   Arena de Sao Paulo       Sao Paulo         Uruguay                2
# 794    Estadio das Dunas           Natal           Japan                0
# 795     Arena Pernambuco          Recife           Italy                0
# 796     Arena Fonte Nova        Salvador     Switzerland                2
# 797     Arena da Baixada        Curitiba        Honduras                1
# 798     Estadio Mineirao  Belo Horizonte       Argentina                1
# 799     Estadio Castelao       Fortaleza         Germany                2
# 800       Arena Pantanal          Cuiaba         Nigeria                1
# 801  Estadio do Maracana  Rio De Janeiro         Belgium                1
# ..                   ...              ...            ...              ...
# 822     Estadio Nacional        Brasilia          France                2
# 823    Estadio Beira-Rio    Porto Alegre         Germany                2
# 824     Estadio Castelao       Fortaleza          Brazil                2
# 825  Estadio do Maracana  Rio De Janeiro          France                0
# 826     Estadio Mineirao  Belo Horizonte          Brazil                1
# 827     Estadio Nacional        Brasilia          Brazil                0
# 828  Estadio do Maracana  Rio De Janeiro         Germany                1
# 829   Arena de Sao Paulo       Sao Paulo     Netherlands                0
# 830     Arena Fonte Nova        Salvador     Netherlands                0
# 831     Estadio Nacional        Brasilia       Argentina                1
# 832     Estadio Castelao       Fortaleza     Netherlands                2
# 833     Arena Pernambuco          Recife      Costa Rica                1
# 834   Arena de Sao Paulo       Sao Paulo       Argentina                1
# 835     Arena Fonte Nova        Salvador         Belgium                2
# 836     Estadio Mineirao  Belo Horizonte          Brazil                1
# 837  Estadio do Maracana  Rio De Janeiro        Colombia                2
# 838     Estadio Castelao       Fortaleza     Netherlands                2
# 839     Arena Pernambuco          Recife      Costa Rica                1
# 840     Estadio Nacional        Brasilia          France                2
# 841    Estadio Beira-Rio    Porto Alegre         Germany                2
# 842   Arena de Sao Paulo       Sao Paulo       Argentina                1
# 843     Arena Fonte Nova        Salvador         Belgium                2
# 844  Estadio do Maracana  Rio De Janeiro          France                0
# 845     Estadio Castelao       Fortaleza          Brazil                2
# 846     Estadio Nacional        Brasilia       Argentina                1
# 847     Arena Fonte Nova        Salvador     Netherlands                0
# 848     Estadio Mineirao  Belo Horizonte          Brazil                1
# 849   Arena de Sao Paulo       Sao Paulo     Netherlands                0
# 850     Estadio Nacional        Brasilia          Brazil                0
# 851  Estadio do Maracana  Rio De Janeiro         Germany                1
#
#      Away Team Goals              Away Team Name  \
# 772                1                     Croatia
# 773                0                    Cameroon
# 774                5                 Netherlands
# 775                1                   Australia
# 776                0                      Greece
# 777                3                  Costa Rica
# 778                2                       Italy
# 779                1                       Japan
# 780                1                     Ecuador
# 781                0                    Honduras
# 782                1  rn">Bosnia and Herzegovina
# 783                0                    Portugal
# 784                0                     Nigeria
# 785                2                         USA
# 786                1                     Algeria
# 787                0                      Mexico
# 788                1              Korea Republic
# 789                3                 Netherlands
# 790                2                       Chile
# 791                4                     Croatia
# 792                1               C�te d'Ivoire
# 793                1                     England
# 794                0                      Greece
# 795                1                  Costa Rica
# 796                5                      France
# 797                2                     Ecuador
# 798                0                     IR Iran
# 799                2                       Ghana
# 800                0  rn">Bosnia and Herzegovina
# 801                0                      Russia
# ..               ...                         ...
# 822                0                     Nigeria
# 823                1                     Algeria
# 824                1                    Colombia
# 825                1                     Germany
# 826                7                     Germany
# 827                3                 Netherlands
# 828                0                   Argentina
# 829                0                   Argentina
# 830                0                  Costa Rica
# 831                0                     Belgium
# 832                1                      Mexico
# 833                1                      Greece
# 834                0                 Switzerland
# 835                1                         USA
# 836                1                       Chile
# 837                0                     Uruguay
# 838                1                      Mexico
# 839                1                      Greece
# 840                0                     Nigeria
# 841                1                     Algeria
# 842                0                 Switzerland
# 843                1                         USA
# 844                1                     Germany
# 845                1                    Colombia
# 846                0                     Belgium
# 847                0                  Costa Rica
# 848                7                     Germany
# 849                0                   Argentina
# 850                3                 Netherlands
# 851                0                   Argentina
#
#                             Win conditions  Attendance  Half-time Home Goals  \
# 772                                            62103.0                     1
# 773                                            39216.0                     0
# 774                                            48173.0                     1
# 775                                            40275.0                     2
# 776                                            57174.0                     1
# 777                                            58679.0                     1
# 778                                            39800.0                     1
# 779                                            40267.0                     0
# 780                                            68351.0                     0
# 781                                            43012.0                     1
# 782                                            74738.0                     1
# 783                                            51081.0                     3
# 784                                            39081.0                     0
# 785                                            39760.0                     0
# 786                                            56800.0                     0
# 787                                            60342.0                     0
# 788                                            37603.0                     0
# 789                                            42877.0                     1
# 790                                            74101.0                     0
# 791                                            39982.0                     0
# 792                                            68748.0                     0
# 793                                            62575.0                     1
# 794                                            39485.0                     0
# 795                                            40285.0                     0
# 796                                            51003.0                     0
# 797                                            39224.0                     1
# 798                                            57698.0                     0
# 799                                            59621.0                     0
# 800                                            40499.0                     1
# 801                                            73819.0                     0
# ..                                     ...         ...                   ...
# 822                                            67882.0                     0
# 823          Germany win after extra time          NaN                     0
# 824                                            60342.0                     1
# 825                                            74240.0                     0
# 826                                            58141.0                     0
# 827                                            68034.0                     0
# 828          Germany win after extra time      74738.0                     0
# 829    Argentina win on penalties (2 - 4)      63267.0                     0
# 830  Netherlands win on penalties (4 - 3)      51179.0                     0
# 831                                            68551.0                     1
# 832                                            58817.0                     0
# 833   Costa Rica win on penalties (5 - 3)      41242.0                     0
# 834        Argentina win after extra time      63255.0                     0
# 835          Belgium win after extra time      51227.0                     0
# 836       Brazil win on penalties (3 - 2)      57714.0                     0
# 837                                            73804.0                     1
# 838                                            58817.0                     0
# 839   Costa Rica win on penalties (5 - 3)      41242.0                     0
# 840                                            67882.0                     0
# 841          Germany win after extra time          NaN                     0
# 842        Argentina win after extra time      63255.0                     0
# 843          Belgium win after extra time      51227.0                     0
# 844                                            74240.0                     0
# 845                                            60342.0                     1
# 846                                            68551.0                     1
# 847  Netherlands win on penalties (4 - 3)      51179.0                     0
# 848                                            58141.0                     0
# 849    Argentina win on penalties (2 - 4)      63267.0                     0
# 850                                            68034.0                     0
# 851          Germany win after extra time      74738.0                     0
#
#      Half-time Away Goals                        Referee  \
# 772                     1         NISHIMURA Yuichi (JPN)
# 773                     0            ROLDAN Wilmar (COL)
# 774                     1           Nicola RIZZOLI (ITA)
# 775                     1          Noumandiez DOUE (CIV)
# 776                     0              GEIGER Mark (USA)
# 777                     0              BRYCH Felix (GER)
# 778                     1            Bj�rn KUIPERS (NED)
# 779                     1            OSSES Enrique (CHI)
# 780                     1          Ravshan IRMATOV (UZB)
# 781                     0             RICCI Sandro (BRA)
# 782                     0             AGUILAR Joel (SLV)
# 783                     0            MAZIC Milorad (SRB)
# 784                     0              VERA Carlos (ECU)
# 785                     1           ERIKSSON Jonas (SWE)
# 786                     1          RODRIGUEZ Marco (MEX)
# 787                     0             C�neyt �AKIR (TUR)
# 788                     0            PITANA Nestor (ARG)
# 789                     1          HAIMOUDI Djamel (ALG)
# 790                     2              GEIGER Mark (USA)
# 791                     1            PROENCA Pedro (POR)
# 792                     0              WEBB Howard (ENG)
# 793                     0  Carlos VELASCO CARBALLO (ESP)
# 794                     0             AGUILAR Joel (SLV)
# 795                     1            OSSES Enrique (CHI)
# 796                     3            Bj�rn KUIPERS (NED)
# 797                     1             Ben WILLIAMS (AUS)
# 798                     0            MAZIC Milorad (SRB)
# 799                     0             RICCI Sandro (BRA)
# 800                     0            Peter O'LEARY (NZL)
# 801                     0              BRYCH Felix (GER)
# ..                    ...                            ...
# 822                     0              GEIGER Mark (USA)
# 823                     0             RICCI Sandro (BRA)
# 824                     0  Carlos VELASCO CARBALLO (ESP)
# 825                     1            PITANA Nestor (ARG)
# 826                     5          RODRIGUEZ Marco (MEX)
# 827                     2          HAIMOUDI Djamel (ALG)
# 828                     0           Nicola RIZZOLI (ITA)
# 829                     0             C�neyt �AKIR (TUR)
# 830                     0          Ravshan IRMATOV (UZB)
# 831                     0           Nicola RIZZOLI (ITA)
# 832                     0            PROENCA Pedro (POR)
# 833                     0             Ben WILLIAMS (AUS)
# 834                     0           ERIKSSON Jonas (SWE)
# 835                     0          HAIMOUDI Djamel (ALG)
# 836                     0              WEBB Howard (ENG)
# 837                     0            Bj�rn KUIPERS (NED)
# 838                     0            PROENCA Pedro (POR)
# 839                     0             Ben WILLIAMS (AUS)
# 840                     0              GEIGER Mark (USA)
# 841                     0             RICCI Sandro (BRA)
# 842                     0           ERIKSSON Jonas (SWE)
# 843                     0          HAIMOUDI Djamel (ALG)
# 844                     1            PITANA Nestor (ARG)
# 845                     0  Carlos VELASCO CARBALLO (ESP)
# 846                     0           Nicola RIZZOLI (ITA)
# 847                     0          Ravshan IRMATOV (UZB)
# 848                     5          RODRIGUEZ Marco (MEX)
# 849                     0             C�neyt �AKIR (TUR)
# 850                     2          HAIMOUDI Djamel (ALG)
# 851                     0           Nicola RIZZOLI (ITA)
#
#                         Assistant 1                    Assistant 2  RoundID  \
# 772               SAGARA Toru (JPN)           NAGI Toshiyuki (JPN)   255931
# 773          CLAVIJO Humberto (COL)             DIAZ Eduardo (COL)   255931
# 774           Renato FAVERANI (ITA)           Andrea STEFANI (ITA)   255931
# 775            YEO Songuifolo (CIV)  BIRUMUSHAHU Jean Claude (BDI)   255931
# 776                 HURD Sean (USA)             FLETCHER Joe (CAN)   255931
# 777               BORSCH Mark (GER)              LUPP Stefan (GER)   255931
# 778         Sander VAN ROEKEL (NED)           Erwin ZEINSTRA (NED)   255931
# 779            ASTROZA Carlos (CHI)             ROMAN Sergio (CHI)   255931
# 780     RASULOV Abduxamidullo (UZB)       KOCHKAROV Bakhadyr (KGZ)   255931
# 781       DE CARVALHO Emerson (BRA)        VAN GASSE Marcelo (BRA)   255931
# 782            TORRES William (SLV)               ZUMBA Juan (SLV)   255931
# 783            RISTIC Milovan (SRB)       DJURDJEVIC Dalibor (SRB)   255931
# 784         LESCANO Christian (ECU)             ROMERO Byron (ECU)   255931
# 785         KLASENIUS Mathias (SWE)          WARNMARK Daniel (SWE)   255931
# 786         TORRENTERA Marvin (MEX)          QUINTERO Marcos (MEX)   255931
# 787            DURAN Bahattin (TUR)              ONGUN Tarik (TUR)   255931
# 788            MAIDANA Hernan (ARG)       BELATTI Juan Pablo (ARG)   255931
# 789            ACHIK Redouane (MAR)        ETCHIALI Abdelhak (ALG)   255931
# 790                 HURD Sean (USA)             FLETCHER Joe (CAN)   255931
# 791           MIRANDA Bertino (POR)               TRIGO Jose (POR)   255931
# 792         MULLARKEY Michael (ENG)              Darren CANN (ENG)   255931
# 793  ALONSO FERNANDEZ Roberto (ESP)               YUSTE Juan (ESP)   255931
# 794            TORRES William (SLV)               ZUMBA Juan (SLV)   255931
# 795            ASTROZA Carlos (CHI)             ROMAN Sergio (CHI)   255931
# 796         Sander VAN ROEKEL (NED)           Erwin ZEINSTRA (NED)   255931
# 797             CREAM Matthew (AUS)               ANAZ Hakan (AUS)   255931
# 798            RISTIC Milovan (SRB)       DJURDJEVIC Dalibor (SRB)   255931
# 799       DE CARVALHO Emerson (BRA)        VAN GASSE Marcelo (BRA)   255931
# 800         HINTZ Jan Hendrik (NZL)                RULE Mark (NZL)   255931
# 801               BORSCH Mark (GER)              LUPP Stefan (GER)   255931
# ..                              ...                            ...      ...
# 822                 HURD Sean (USA)             FLETCHER Joe (CAN)   255951
# 823       DE CARVALHO Emerson (BRA)        VAN GASSE Marcelo (BRA)   255951
# 824  ALONSO FERNANDEZ Roberto (ESP)               YUSTE Juan (ESP)   255953
# 825            MAIDANA Hernan (ARG)       BELATTI Juan Pablo (ARG)   255953
# 826         TORRENTERA Marvin (MEX)          QUINTERO Marcos (MEX)   255955
# 827            ACHIK Redouane (MAR)        ETCHIALI Abdelhak (ALG)   255957
# 828           Renato FAVERANI (ITA)           Andrea STEFANI (ITA)   255959
# 829            DURAN Bahattin (TUR)              ONGUN Tarik (TUR)   255955
# 830     RASULOV Abduxamidullo (UZB)       KOCHKAROV Bakhadyr (KGZ)   255953
# 831           Renato FAVERANI (ITA)           Andrea STEFANI (ITA)   255953
# 832           MIRANDA Bertino (POR)               TRIGO Jose (POR)   255951
# 833             CREAM Matthew (AUS)               ANAZ Hakan (AUS)   255951
# 834         KLASENIUS Mathias (SWE)          WARNMARK Daniel (SWE)   255951
# 835            ACHIK Redouane (MAR)        ETCHIALI Abdelhak (ALG)   255951
# 836         MULLARKEY Michael (ENG)              Darren CANN (ENG)   255951
# 837         Sander VAN ROEKEL (NED)           Erwin ZEINSTRA (NED)   255951
# 838           MIRANDA Bertino (POR)               TRIGO Jose (POR)   255951
# 839             CREAM Matthew (AUS)               ANAZ Hakan (AUS)   255951
# 840                 HURD Sean (USA)             FLETCHER Joe (CAN)   255951
# 841       DE CARVALHO Emerson (BRA)        VAN GASSE Marcelo (BRA)   255951
# 842         KLASENIUS Mathias (SWE)          WARNMARK Daniel (SWE)   255951
# 843            ACHIK Redouane (MAR)        ETCHIALI Abdelhak (ALG)   255951
# 844            MAIDANA Hernan (ARG)       BELATTI Juan Pablo (ARG)   255953
# 845  ALONSO FERNANDEZ Roberto (ESP)               YUSTE Juan (ESP)   255953
# 846           Renato FAVERANI (ITA)           Andrea STEFANI (ITA)   255953
# 847     RASULOV Abduxamidullo (UZB)       KOCHKAROV Bakhadyr (KGZ)   255953
# 848         TORRENTERA Marvin (MEX)          QUINTERO Marcos (MEX)   255955
# 849            DURAN Bahattin (TUR)              ONGUN Tarik (TUR)   255955
# 850            ACHIK Redouane (MAR)        ETCHIALI Abdelhak (ALG)   255957
# 851           Renato FAVERANI (ITA)           Andrea STEFANI (ITA)   255959
#
#        MatchID Home Team Initials Away Team Initials
# 772  300186456                BRA                CRO
# 773  300186492                MEX                CMR
# 774  300186510                ESP                NED
# 775  300186473                CHI                AUS
# 776  300186471                COL                GRE
# 777  300186489                URU                CRC
# 778  300186513                ENG                ITA
# 779  300186507                CIV                JPN
# 780  300186494                SUI                ECU
# 781  300186496                FRA                HON
# 782  300186477                ARG                BIH
# 783  300186475                GER                POR
# 784  300186505                IRN                NGA
# 785  300186512                GHA                USA
# 786  300186479                BEL                ALG
# 787  300186509                BRA                MEX
# 788  300186499                RUS                KOR
# 789  300186478                AUS                NED
# 790  300186498                ESP                CHI
# 791  300186453                CMR                CRO
# 792  300186468                COL                CIV
# 793  300186486                URU                ENG
# 794  300186454                JPN                GRE
# 795  300186500                ITA                CRC
# 796  300186514                SUI                FRA
# 797  300186463                HON                ECU
# 798  300186466                ARG                IRN
# 799  300186493                GER                GHA
# 800  300186511                NGA                BIH
# 801  300186481                BEL                RUS
# ..         ...                ...                ...
# 822  300186462                FRA                NGA
# 823  300186460                GER                ALG
# 824  300186461                BRA                COL
# 825  300186485                FRA                GER
# 826  300186474                BRA                GER
# 827  300186502                BRA                NED
# 828  300186501                GER                ARG
# 829  300186490                NED                ARG
# 830  300186488                NED                CRC
# 831  300186504                ARG                BEL
# 832  300186508                NED                MEX
# 833  300186459                CRC                GRE
# 834  300186503                ARG                SUI
# 835  300186497                BEL                USA
# 836  300186487                BRA                CHI
# 837  300186491                COL                URU
# 838  300186508                NED                MEX
# 839  300186459                CRC                GRE
# 840  300186462                FRA                NGA
# 841  300186460                GER                ALG
# 842  300186503                ARG                SUI
# 843  300186497                BEL                USA
# 844  300186485                FRA                GER
# 845  300186461                BRA                COL
# 846  300186504                ARG                BEL
# 847  300186488                NED                CRC
# 848  300186474                BRA                GER
# 849  300186490                NED                ARG
# 850  300186502                BRA                NED
# 851  300186501                GER                ARG
#
# [80 rows x 20 columns]

# %% [markdown]
# Now, let's try to find out how many countries participated in the 1986 world cup.

# %% [markdown]
# Hint 1: as a first step, create a new data set that only contain games in that year.
#
# Hint 2: You can use `.unique()` to make sure you don't end up with duplicate country names.

# %% [markdown]
# In the world cup history, how matches had more than 5 goals in total?

# %% [markdown]
# ## Changing values and creating new columns

# %% [markdown]
# With the information you currently have in your `df`, create a new column "Half-time Goals".

# %% [markdown]
# Run the code below. You'll notice that for Korea, there are records for both North-Korea (Korea DPR) and South-Korea (Korea Republic).

# %%
df.loc[df["Home Team Name"].str.contains('Korea'), "Home Team Name" ]

# %% [markdown]
# Imagine that for some reason, we simply want Korea listed as one entry, so we want to replace every "Home Team Name" and "Away Team Name" entry that contains "Korea" to simply "Korea". In the same way, we want to change the columns "Home Team Initials" and "Away Team Initials" to NSK (North & South Korea) instead of "KOR" and "PRK".

# %% [markdown]
# Make sure to verify your answer!

# %% [markdown]
# ## Summary
#
# In this lab, you learned how to access data within Pandas!
